# %% [markdown]
# # Bài tập 1
#
# Nguyễn Ngọc Minh Khánh - 1712525

# %% [markdown]
# ## Câu 1 (1 điểm)

# %% [markdown]
# - Trong những loại máy học được nêu ở 3 trường hợp:
#     - Trường hợp 1: không phải là learning. Chúng ta có 1 mô hình mà nó biết được các đặc tính của đồng tiền. Kiểu như sử dụng nhiều câu kiểm tra về hoa văn, chiều dài, ... kiểm tra nếu đồng tiền có đặc tính này thì mang mệnh giá như sau.
#     - Trường hợp 2: đây là dạng học máy Supervise Learning. Với việc học được cho trước 1 tập dữ liệu lớn với nhãn cho trước và xây dựng 1 model để phân loại.
#     - Trường hợp 3: thuộc về Reinforcement Learning( Học tăng cường ). Thôi em biết thì thuật toán được áp dụng nhiều trong gaming, khi nó học từ việc cố gắng tự chơi với chính nó và trừng phạt nặng những bước chọn mà không mang lại hiệu quả cao.

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [d]

# %% [markdown]
# ## Câu 2 (1 điểm)

# %% [markdown]
#  - Dưới dây có 4 trường hợp:
#      - Trường hợp 1: Không phù hợp cho machine learning vì chúng ta có thể xây dựng được 1 mô hình toán học.
#      - Trường hợp 2: Phù hợp để áp dụng machine learning vì tồn tại pattern, không thể xây dựng được công thức toán học và có dữ liệu cho huấn luyện.
#      - Trường hợp 3: Không phù hợp để áp dụng machine learning vì chúng ta có thể xây dựng 1 công thức toán học cho nó.
#      - Trường hợp 4:Phù hợp để áp dụng machine learning vì tồn tại mô hình, không thể xây dựng được công thức toán học và có dữ liệu cho huấn luyện.

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [a]

# %% [markdown]
# ## Câu 3 (1 điểm)

# %% [markdown]
# - Xác suất chọn của 2 túi là như nhau. Và đã bốc được 1 viên bi đen ở lần chọn thứ nhất. Ta dùng xác suất có điều kiện
# P(bi2đen | bi1đen) = P(bi2đen and bi1đen) / P(bi1đen).
# -  P(bi2đen and bi1đen) = 0.5
# -  P(bi1đen) = 3/4
# => Xác suất để bi 2 đen là 2/3

# %% [markdown]
# YOUR ANSWER HERE
#  - Do đó em chọn đáp án [d]

# %% [markdown]
# ## Câu 4 (1 điểm)

# %% [markdown]
#  - Xác suất để không lấy được viên bi đỏ nào hết là Z:
#  $$ Z =  {(1-\mu)}^{10} $$

# %%
Z = (1-0.55)**10
Z
# Out:
# 0.0003405062891601559

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [b]

# %% [markdown]
# ## Câu 5 (1 điểm)

# %% [markdown]
# - Đề bài là xác suất trong 1000 lần thực nghiệm có ít nhất 1 lần không lấy được viên bi đỏ nào.
# - Gọi P là xác suất để không có lần thực nghiệm nào mà không bốc được bất kì viên bi đỏ: $$ P = (1-Z)^{1000} $$
# - Vậy xác xuất đối ngẫu để có ít nhất 1 lần thực nghiệm mà không bốc được bất kì viên bi đỏ là: 1-P

# %%
P = (1-Z)**1000
kq = 1-P
kq
# Out:
# 0.28863119784980995

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [c]

# %% [markdown]
# ## Câu 6 (1 điểm)

# %% [markdown]
# - Đề bài mình còn thiếu 3 dữ liệu 101, 110, 111
# - Do còn thiếu 3 điểm dữ liệu nên khả năng của f ta chưa biết có thể là 000, 001, 010, 011, 100, 101, 110, 111. Với 000 là điểm 101 có y_n = 0, 110 có y_n = 0 và 111 có y_n=0
# - Dựa vào hàm g đã cho ở a,b,c,d để tính điểm và xem hàm g nào gần f nhất
#     - Câu a: trả về 1 cho cả 3 điểm dữ liệu nên y = 111. Giờ kiểm tra xem trong 8 hàm f bao nhiêu hàm thỏa 3, 2, 1, 0.
#         - Có 1 function thỏa 3 điểm là 111
#         - 3 function thỏa 2 điểm là: 110, 101, 011
#         - 3 function thỏa 1 điểm là: 001, 100, 010
#         - 1 function thỏa 0 điểm là: 000
#         --> 3*1+3*2+3*1 = 12
#     - Câu b: Trả về 000 cho 3 điểm dữ liệu nên y = 000. Giờ kiểm tra xem trong 8 hàm f bao nhiêu hàm thỏa 3, 2, 1, 0.
#         - Có 1 hàm thỏa 3 điểm là: 000
#         - 3 hàm thỏa 2 điểm là: 001, 010, 100
#         - 3 hàm thỏa 1 điểm là: 110, 101, 011
#         - 1 hàm thỏa 0 điểm là: 111
#         --> 3*1 + 3*2+ 3*1 = 12
#     - Câu c, d làm tương tự và cho cùng số điểm là 12.

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [c]

# %% [markdown]
# ## Câu 7 (1 điểm)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist

# %%
def randomPoint(lower, upper, dim): 
    X = np.random.uniform(lower, upper, dim)
    return X

# %%
def getLabel(point_1, point_2, random_point):
    """
    You can search how to know the point being above or being below the line. (trick)
    int. +1 for the point being above the line. -1 for the point being below the line. 0 otherwise.
    Check further infor: https://stackoverflow.com/questions/3838319/how-can-i-check-if-a-point-is-below-a-line-or-not
                       or https://math.stackexchange.com/questions/274712/calculate-on-which-side-of-a-straight-line-is-a-given-point-located.
    You need to draw in the white broad to see why ?
    """
    if point_1[0] < point_2[0]:
        minus_of_point_of_line = (point_1[0]-point_2[0], point_1[1]-point_2[1])
    else: minus_of_point_of_line = (point_2[0]-point_1[0], point_2[1]-point_1[1])
    
    if point_1[1] < point_2[1]:
         minus_of_randomPoint_and_point = (random_point[0] - point_1[0], random_point[1]-point_1[1])
    else:  minus_of_randomPoint_and_point = (random_point[0] - point_2[0], random_point[1]-point_2[1])
    
    return np.sign( minus_of_point_of_line[1]*minus_of_randomPoint_and_point[0] -
                  minus_of_point_of_line[0]*minus_of_randomPoint_and_point[1])

# %%
def generate_X(N):
    # Create X train 
    X = [randomPoint(-1, 1, 2) for i in range(0, N)]
    X = np.array(X) # shape(N, 2)
    
    return X

# %%
def corresponding_Y(X):
    # random 2 point for the line seperately data and get label corresponding
    point_1_OfLine = randomPoint(-1, 1, 2) #shape (1, 2)
    point_2_OfLine = randomPoint(-1, 1, 2)
    
    # -1 for the point being above the line. -1 for the point being below the line. 0 otherwise.
    y = [getLabel(point_1_OfLine, point_2_OfLine, x) for x in X]
    y = np.array(y)
    return y

# %%
def train_test_split(X, y, n_points):
    n = X.shape[0]
    index = np.arange(n)
    np.random.shuffle(index) # random index
#     number_of_element_train = int(np.round(0.2*n)) # get 20% of data
    #print(number_of_element_train)
    # train
    X_train = X[index[:n_points], :]
    X_test = X[index[n_points:], :]
    # test
    y_train = y[index[:n_points]]
    y_test = y[index[n_points:]]
    
    return X_train, X_test, y_train, y_test

# %%
class PLA:
    """Perceptron learning algorithm (PLA) class"""
    def __init__(self, initialWeights, trainingSet, y):
        """Create a new perceptron learning algorithm (PLA)
        Args:
        
        """
        self.initialWeights = initialWeights
        self.trainingSet = trainingSet
        self.y = y
    
    def  predict(self, w):
        return np.sign(self.trainingSet.dot(w))
    
    def run(self, maxIterations = 10000):
        """Run perceptron learning algorithm """
        w = self.initialWeights
        X = self.trainingSet
        y = self.y
        
        converged = False
        
        for i in range(0, maxIterations):
            pred = self.predict(w)
            #find the index of misclassifier points
            mis_indexs = np.where(np.equal(pred, y)==False)[0]
            # number of misclassifier points
            num_mis = mis_indexs.shape[0]
            #print(num_mis)
            
            if num_mis == 0:# no more misclassifier point
                converged = True
                return w, i
                
            # random pick one misclassifier points
            random_id = np.random.choice(mis_indexs, 1)[0]
            #update w
            w = w + y[random_id] * X[random_id]
            
        if converged == False:
            print("Perceptron algorithm failed to converge after maximum number of iterations")

# %%
# Sáng mai tính tiếp hàm loop cho PLA
def runPerceptron(n_loops=100, n_points = 10):
    sumOfIteration = 0
    sumDisagreementProb = 0
    
    print(n_loops)

    for i in range(n_loops):
        X = generate_X(n_points + 1000) # 1000 for test set
        y = corresponding_Y(X) # get labels correspondingly

        X = np.concatenate((np.ones((X.shape[0], 1)), X), axis = 1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, n_points)
        
        w0 = np.zeros(X.shape[1])
        pla = PLA(w0, X_train, y_train)
        #run PLA
        w_converged, iterations = pla.run()
        print("PLA converged after %d iterations ", iterations)
        
        # update the number of iterations
        sumOfIteration += iterations

        # calculate the probability of the disagreement between f and g which is P[f(x) != g(x)] 
        y_predict = np.sign(X_test.dot(w_converged))
        mis_indexs = np.where(np.equal(y_predict, y_test)==False)[0] # the number of the disagreement between f and g
        num_mis = mis_indexs.shape[0]
        sumDisagreementProb += float(num_mis/X_test.shape[0])


    mean_disagreementProb = sumDisagreementProb / n_loops
    mean_iterations = sumOfIteration /n_loops
    
    return mean_iterations, mean_disagreementProb

    print("The average number of iterations = ", mean_iterations)
    print("the average disagreement probability between f and g = ", mean_disagreementProb)

# %%
mean_iterations, mean_disagreementProb = runPerceptron(n_loops = 10, n_points = 10)

print("----------------------------------")
print("The average number of iterations = ", mean_iterations)
# Out:
# 1000
# PLA converged after %d iterations  2
# PLA converged after %d iterations  23
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  64
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  7
# PLA converged after %d iterations  17
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  8
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  24
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  11
# PLA converged after %d iterations  9
# PLA converged after %d iterations  12
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  23
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  25
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  13
# PLA converged after %d iterations  1
# PLA converged after %d iterations  6
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  13
# PLA converged after %d iterations  20
# PLA converged after %d iterations  3
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  14
# PLA converged after %d iterations  15
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  11
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  15
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  19
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  14
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  11
# PLA converged after %d iterations  15
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  33
# PLA converged after %d iterations  1
# PLA converged after %d iterations  11
# PLA converged after %d iterations  20
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  13
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  12
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  12
# PLA converged after %d iterations  6
# PLA converged after %d iterations  5
# PLA converged after %d iterations  18
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  5
# PLA converged after %d iterations  13
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  10
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  11
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  73
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  9
# PLA converged after %d iterations  1
# PLA converged after %d iterations  19
# PLA converged after %d iterations  9
# PLA converged after %d iterations  10
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  29
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  8
# PLA converged after %d iterations  3
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  31
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  22
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  17
# PLA converged after %d iterations  7
# PLA converged after %d iterations  21
# PLA converged after %d iterations  12
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  33
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  5
# PLA converged after %d iterations  8
# PLA converged after %d iterations  22
# PLA converged after %d iterations  1
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  7
# PLA converged after %d iterations  16
# PLA converged after %d iterations  18
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  17
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  9
# PLA converged after %d iterations  9
# PLA converged after %d iterations  6
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  16
# PLA converged after %d iterations  9
# PLA converged after %d iterations  153
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  10
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  13
# PLA converged after %d iterations  20
# PLA converged after %d iterations  11
# PLA converged after %d iterations  10
# PLA converged after %d iterations  27
# PLA converged after %d iterations  14
# PLA converged after %d iterations  1
# PLA converged after %d iterations  17
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  8
# PLA converged after %d iterations  35
# PLA converged after %d iterations  34
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  12
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  18
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  44
# PLA converged after %d iterations  5
# PLA converged after %d iterations  10
# PLA converged after %d iterations  12
# PLA converged after %d iterations  5
# PLA converged after %d iterations  23
# PLA converged after %d iterations  7
# PLA converged after %d iterations  20
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  20
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  14
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  8
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  17
# PLA converged after %d iterations  20
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  25
# PLA converged after %d iterations  4
# PLA converged after %d iterations  8
# PLA converged after %d iterations  13
# PLA converged after %d iterations  19
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  8
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  36
# PLA converged after %d iterations  15
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  103
# PLA converged after %d iterations  17
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  11
# PLA converged after %d iterations  5
# PLA converged after %d iterations  16
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  81
# PLA converged after %d iterations  4
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  6
# PLA converged after %d iterations  12
# PLA converged after %d iterations  4
# PLA converged after %d iterations  3
# PLA converged after %d iterations  8
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  16
# PLA converged after %d iterations  27
# PLA converged after %d iterations  9
# PLA converged after %d iterations  99
# PLA converged after %d iterations  3
# PLA converged after %d iterations  9
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  33
# PLA converged after %d iterations  13
# PLA converged after %d iterations  9
# PLA converged after %d iterations  11
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  115
# PLA converged after %d iterations  4
# PLA converged after %d iterations  23
# PLA converged after %d iterations  13
# PLA converged after %d iterations  15
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  45
# PLA converged after %d iterations  4
# PLA converged after %d iterations  33
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  9
# PLA converged after %d iterations  12
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  6
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  33
# PLA converged after %d iterations  17
# PLA converged after %d iterations  21
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  17
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  14
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  15
# PLA converged after %d iterations  105
# PLA converged after %d iterations  9
# PLA converged after %d iterations  4
# PLA converged after %d iterations  25
# PLA converged after %d iterations  5
# PLA converged after %d iterations  15
# PLA converged after %d iterations  6
# PLA converged after %d iterations  39
# PLA converged after %d iterations  7
# PLA converged after %d iterations  10
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  23
# PLA converged after %d iterations  39
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  27
# PLA converged after %d iterations  21
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  9
# PLA converged after %d iterations  6
# PLA converged after %d iterations  5
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  11
# PLA converged after %d iterations  7
# PLA converged after %d iterations  8
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  10
# PLA converged after %d iterations  31
# PLA converged after %d iterations  2
# PLA converged after %d iterations  51
# PLA converged after %d iterations  9
# PLA converged after %d iterations  8
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  36
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  10
# PLA converged after %d iterations  15
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  9
# PLA converged after %d iterations  1
# PLA converged after %d iterations  6
# PLA converged after %d iterations  8
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  11
# PLA converged after %d iterations  8
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  10
# PLA converged after %d iterations  15
# PLA converged after %d iterations  10
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  8
# PLA converged after %d iterations  7
# PLA converged after %d iterations  19
# PLA converged after %d iterations  4
# PLA converged after %d iterations  12
# PLA converged after %d iterations  10
# PLA converged after %d iterations  3
# PLA converged after %d iterations  6
# PLA converged after %d iterations  12
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  13
# PLA converged after %d iterations  9
# PLA converged after %d iterations  4
# PLA converged after %d iterations  13
# PLA converged after %d iterations  30
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  19
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  153
# PLA converged after %d iterations  5
# PLA converged after %d iterations  10
# PLA converged after %d iterations  10
# PLA converged after %d iterations  3
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  16
# PLA converged after %d iterations  13
# PLA converged after %d iterations  5
# PLA converged after %d iterations  23
# PLA converged after %d iterations  5
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  17
# PLA converged after %d iterations  7
# PLA converged after %d iterations  13
# PLA converged after %d iterations  3
# PLA converged after %d iterations  11
# PLA converged after %d iterations  18
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  20
# PLA converged after %d iterations  20
# PLA converged after %d iterations  8
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  15
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  51
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  26
# PLA converged after %d iterations  6
# PLA converged after %d iterations  5
# PLA converged after %d iterations  17
# PLA converged after %d iterations  3
# PLA converged after %d iterations  16
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  15
# PLA converged after %d iterations  18
# PLA converged after %d iterations  12
# PLA converged after %d iterations  9
# PLA converged after %d iterations  14
# PLA converged after %d iterations  9
# PLA converged after %d iterations  33
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  10
# PLA converged after %d iterations  1
# PLA converged after %d iterations  8
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  7
# PLA converged after %d iterations  28
# PLA converged after %d iterations  7
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  15
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  8
# PLA converged after %d iterations  3
# PLA converged after %d iterations  11
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  27
# PLA converged after %d iterations  7
# PLA converged after %d iterations  13
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  11
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  9
# PLA converged after %d iterations  103
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  15
# PLA converged after %d iterations  4
# PLA converged after %d iterations  10
# PLA converged after %d iterations  7
# PLA converged after %d iterations  12
# PLA converged after %d iterations  1
# PLA converged after %d iterations  16
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  10
# PLA converged after %d iterations  3
# PLA converged after %d iterations  8
# PLA converged after %d iterations  20
# PLA converged after %d iterations  9
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  15
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  28
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  65
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  9
# PLA converged after %d iterations  11
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  4
# PLA converged after %d iterations  13
# PLA converged after %d iterations  3
# PLA converged after %d iterations  9
# PLA converged after %d iterations  9
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  13
# PLA converged after %d iterations  7
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  10
# PLA converged after %d iterations  4
# PLA converged after %d iterations  24
# PLA converged after %d iterations  3
# PLA converged after %d iterations  8
# PLA converged after %d iterations  20
# PLA converged after %d iterations  13
# PLA converged after %d iterations  17
# PLA converged after %d iterations  18
# PLA converged after %d iterations  7
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  11
# PLA converged after %d iterations  4
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  9
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  61
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  9
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  9
# PLA converged after %d iterations  9
# PLA converged after %d iterations  77
# PLA converged after %d iterations  3
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  12
# PLA converged after %d iterations  18
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  55
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  6
# PLA converged after %d iterations  7
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  8
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  8
# PLA converged after %d iterations  4
# PLA converged after %d iterations  17
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  9
# PLA converged after %d iterations  2
# PLA converged after %d iterations  8
# PLA converged after %d iterations  14
# PLA converged after %d iterations  2
# PLA converged after %d iterations  17
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  19
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  15
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  12
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  47
# PLA converged after %d iterations  5
# PLA converged after %d iterations  24
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  4
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  93
# PLA converged after %d iterations  5
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  9
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  16
# PLA converged after %d iterations  89
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  9
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  6
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  9
# PLA converged after %d iterations  6
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  34
# PLA converged after %d iterations  18
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  4
# PLA converged after %d iterations  16
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  8
# PLA converged after %d iterations  11
# PLA converged after %d iterations  4
# PLA converged after %d iterations  7
# PLA converged after %d iterations  1
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  23
# PLA converged after %d iterations  13
# PLA converged after %d iterations  5
# PLA converged after %d iterations  25
# PLA converged after %d iterations  3
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  32
# PLA converged after %d iterations  74
# PLA converged after %d iterations  7
# PLA converged after %d iterations  43
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  25
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  6
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  9
# PLA converged after %d iterations  7
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  17
# PLA converged after %d iterations  11
# PLA converged after %d iterations  9
# PLA converged after %d iterations  12
# PLA converged after %d iterations  1
# PLA converged after %d iterations  16
# PLA converged after %d iterations  5
# PLA converged after %d iterations  7
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  1
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# PLA converged after %d iterations  10
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  24
# PLA converged after %d iterations  17
# PLA converged after %d iterations  30
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  132
# PLA converged after %d iterations  6
# PLA converged after %d iterations  17
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  2
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  9
# PLA converged after %d iterations  19
# PLA converged after %d iterations  1
# PLA converged after %d iterations  7
# PLA converged after %d iterations  6
# PLA converged after %d iterations  35
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  41
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  48
# PLA converged after %d iterations  8
# PLA converged after %d iterations  4
# PLA converged after %d iterations  9
# PLA converged after %d iterations  7
# PLA converged after %d iterations  12
# PLA converged after %d iterations  20
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  4
# PLA converged after %d iterations  7
# PLA converged after %d iterations  7
# PLA converged after %d iterations  5
# PLA converged after %d iterations  3
# PLA converged after %d iterations  5
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  23
# PLA converged after %d iterations  2
# PLA converged after %d iterations  11
# PLA converged after %d iterations  7
# PLA converged after %d iterations  27
# PLA converged after %d iterations  6
# PLA converged after %d iterations  11
# PLA converged after %d iterations  1
# PLA converged after %d iterations  29
# PLA converged after %d iterations  2
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  62
# PLA converged after %d iterations  4
# PLA converged after %d iterations  1
# PLA converged after %d iterations  22
# PLA converged after %d iterations  9
# PLA converged after %d iterations  3
# PLA converged after %d iterations  47
# PLA converged after %d iterations  13
# PLA converged after %d iterations  9
# PLA converged after %d iterations  9
# PLA converged after %d iterations  6
# PLA converged after %d iterations  7
# PLA converged after %d iterations  15
# PLA converged after %d iterations  1
# PLA converged after %d iterations  15
# PLA converged after %d iterations  6
# PLA converged after %d iterations  53
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  1
# PLA converged after %d iterations  8
# PLA converged after %d iterations  1
# PLA converged after %d iterations  3
# PLA converged after %d iterations  2
# PLA converged after %d iterations  17
# PLA converged after %d iterations  2
# PLA converged after %d iterations  40
# PLA converged after %d iterations  7
# PLA converged after %d iterations  2
# PLA converged after %d iterations  15
# PLA converged after %d iterations  6
# PLA converged after %d iterations  11
# PLA converged after %d iterations  7
# PLA converged after %d iterations  23
# PLA converged after %d iterations  2
# PLA converged after %d iterations  3
# PLA converged after %d iterations  7
# PLA converged after %d iterations  8
# PLA converged after %d iterations  6
# PLA converged after %d iterations  12
# PLA converged after %d iterations  1
# PLA converged after %d iterations  2
# PLA converged after %d iterations  13
# PLA converged after %d iterations  2
# PLA converged after %d iterations  7
# PLA converged after %d iterations  14
# PLA converged after %d iterations  7
# PLA converged after %d iterations  18
# PLA converged after %d iterations  4
# PLA converged after %d iterations  11
# PLA converged after %d iterations  3
# PLA converged after %d iterations  10
# PLA converged after %d iterations  4
# PLA converged after %d iterations  15
# PLA converged after %d iterations  7
# PLA converged after %d iterations  9
# PLA converged after %d iterations  3
# PLA converged after %d iterations  85
# PLA converged after %d iterations  38
# PLA converged after %d iterations  4
# PLA converged after %d iterations  4
# PLA converged after %d iterations  15
# PLA converged after %d iterations  1
# PLA converged after %d iterations  25
# PLA converged after %d iterations  15
# PLA converged after %d iterations  2
# PLA converged after %d iterations  1
# ----------------------------------
# The average number of iterations =  9.551

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [b]

# %% [markdown]
# ## Câu 8 (1 điểm)

# %%
print("the average disagreement probability between f and g = ", mean_disagreementProb)
# Out:
# the average disagreement probability between f and g =  0.10931800000000005

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [c]

# %% [markdown]
# ## Câu 9 (1 điểm)

# %%
mean_iterations, mean_disagreementProb = runPerceptron(n_loops = 1000, n_points = 100)

print("----------------------------------")
print("The average number of iterations = ", mean_iterations)
# Out:
# 1000
# PLA converged after %d iterations  66
# PLA converged after %d iterations  172
# PLA converged after %d iterations  163
# PLA converged after %d iterations  5
# PLA converged after %d iterations  56
# PLA converged after %d iterations  181
# PLA converged after %d iterations  54
# PLA converged after %d iterations  206
# PLA converged after %d iterations  22
# PLA converged after %d iterations  357
# PLA converged after %d iterations  68
# PLA converged after %d iterations  267
# PLA converged after %d iterations  171
# PLA converged after %d iterations  73
# PLA converged after %d iterations  1
# PLA converged after %d iterations  143
# PLA converged after %d iterations  415
# PLA converged after %d iterations  73
# PLA converged after %d iterations  152
# PLA converged after %d iterations  100
# PLA converged after %d iterations  85
# PLA converged after %d iterations  62
# PLA converged after %d iterations  15
# PLA converged after %d iterations  193
# PLA converged after %d iterations  313
# PLA converged after %d iterations  10
# PLA converged after %d iterations  90
# PLA converged after %d iterations  47
# PLA converged after %d iterations  27
# PLA converged after %d iterations  98
# PLA converged after %d iterations  16
# PLA converged after %d iterations  28
# PLA converged after %d iterations  125
# PLA converged after %d iterations  33
# PLA converged after %d iterations  28
# PLA converged after %d iterations  21
# PLA converged after %d iterations  102
# PLA converged after %d iterations  167
# PLA converged after %d iterations  24
# PLA converged after %d iterations  95
# PLA converged after %d iterations  29
# PLA converged after %d iterations  52
# PLA converged after %d iterations  26
# PLA converged after %d iterations  115
# PLA converged after %d iterations  77
# PLA converged after %d iterations  81
# PLA converged after %d iterations  137
# PLA converged after %d iterations  12
# PLA converged after %d iterations  37
# PLA converged after %d iterations  81
# PLA converged after %d iterations  37
# PLA converged after %d iterations  71
# PLA converged after %d iterations  15
# PLA converged after %d iterations  33
# PLA converged after %d iterations  101
# PLA converged after %d iterations  201
# PLA converged after %d iterations  45
# PLA converged after %d iterations  26
# PLA converged after %d iterations  65
# PLA converged after %d iterations  167
# PLA converged after %d iterations  275
# PLA converged after %d iterations  234
# PLA converged after %d iterations  165
# PLA converged after %d iterations  34
# PLA converged after %d iterations  105
# PLA converged after %d iterations  79
# PLA converged after %d iterations  126
# PLA converged after %d iterations  55
# PLA converged after %d iterations  17
# PLA converged after %d iterations  75
# PLA converged after %d iterations  16
# PLA converged after %d iterations  88
# PLA converged after %d iterations  371
# PLA converged after %d iterations  26
# PLA converged after %d iterations  46
# PLA converged after %d iterations  374
# PLA converged after %d iterations  26
# PLA converged after %d iterations  47
# PLA converged after %d iterations  64
# PLA converged after %d iterations  759
# PLA converged after %d iterations  381
# PLA converged after %d iterations  161
# PLA converged after %d iterations  52
# PLA converged after %d iterations  68
# PLA converged after %d iterations  93
# PLA converged after %d iterations  157
# PLA converged after %d iterations  85
# PLA converged after %d iterations  41
# PLA converged after %d iterations  27
# PLA converged after %d iterations  58
# PLA converged after %d iterations  72
# PLA converged after %d iterations  57
# PLA converged after %d iterations  85
# PLA converged after %d iterations  68
# PLA converged after %d iterations  25
# PLA converged after %d iterations  71
# PLA converged after %d iterations  209
# PLA converged after %d iterations  9
# PLA converged after %d iterations  78
# PLA converged after %d iterations  128
# PLA converged after %d iterations  47
# PLA converged after %d iterations  79
# PLA converged after %d iterations  2
# PLA converged after %d iterations  64
# PLA converged after %d iterations  65
# PLA converged after %d iterations  22
# PLA converged after %d iterations  134
# PLA converged after %d iterations  48
# PLA converged after %d iterations  126
# PLA converged after %d iterations  42
# PLA converged after %d iterations  37
# PLA converged after %d iterations  201
# PLA converged after %d iterations  16
# PLA converged after %d iterations  52
# PLA converged after %d iterations  15
# PLA converged after %d iterations  26
# PLA converged after %d iterations  113
# PLA converged after %d iterations  118
# PLA converged after %d iterations  62
# PLA converged after %d iterations  38
# PLA converged after %d iterations  416
# PLA converged after %d iterations  22
# PLA converged after %d iterations  85
# PLA converged after %d iterations  51
# PLA converged after %d iterations  40
# PLA converged after %d iterations  69
# PLA converged after %d iterations  23
# PLA converged after %d iterations  85
# PLA converged after %d iterations  153
# PLA converged after %d iterations  26
# PLA converged after %d iterations  24
# PLA converged after %d iterations  141
# PLA converged after %d iterations  309
# PLA converged after %d iterations  25
# PLA converged after %d iterations  38
# PLA converged after %d iterations  24
# PLA converged after %d iterations  209
# PLA converged after %d iterations  129
# PLA converged after %d iterations  36
# PLA converged after %d iterations  263
# PLA converged after %d iterations  181
# PLA converged after %d iterations  43
# PLA converged after %d iterations  156
# PLA converged after %d iterations  140
# PLA converged after %d iterations  44
# PLA converged after %d iterations  18
# PLA converged after %d iterations  57
# PLA converged after %d iterations  293
# PLA converged after %d iterations  42
# PLA converged after %d iterations  51
# PLA converged after %d iterations  49
# PLA converged after %d iterations  61
# PLA converged after %d iterations  37
# PLA converged after %d iterations  37
# PLA converged after %d iterations  86
# PLA converged after %d iterations  124
# PLA converged after %d iterations  98
# PLA converged after %d iterations  73
# PLA converged after %d iterations  22
# PLA converged after %d iterations  27
# PLA converged after %d iterations  35
# PLA converged after %d iterations  122
# PLA converged after %d iterations  45
# PLA converged after %d iterations  99
# PLA converged after %d iterations  37
# PLA converged after %d iterations  99
# PLA converged after %d iterations  32
# PLA converged after %d iterations  110
# PLA converged after %d iterations  346
# PLA converged after %d iterations  99
# PLA converged after %d iterations  29
# PLA converged after %d iterations  75
# PLA converged after %d iterations  11
# PLA converged after %d iterations  244
# PLA converged after %d iterations  56
# PLA converged after %d iterations  54
# PLA converged after %d iterations  93
# PLA converged after %d iterations  33
# PLA converged after %d iterations  185
# PLA converged after %d iterations  52
# PLA converged after %d iterations  70
# PLA converged after %d iterations  340
# PLA converged after %d iterations  19
# PLA converged after %d iterations  20
# PLA converged after %d iterations  152
# PLA converged after %d iterations  62
# PLA converged after %d iterations  148
# PLA converged after %d iterations  11
# PLA converged after %d iterations  31
# PLA converged after %d iterations  235
# PLA converged after %d iterations  19
# PLA converged after %d iterations  178
# PLA converged after %d iterations  45
# PLA converged after %d iterations  293
# PLA converged after %d iterations  13
# PLA converged after %d iterations  14
# PLA converged after %d iterations  75
# PLA converged after %d iterations  84
# PLA converged after %d iterations  165
# PLA converged after %d iterations  32
# PLA converged after %d iterations  45
# PLA converged after %d iterations  35
# PLA converged after %d iterations  29
# PLA converged after %d iterations  25
# PLA converged after %d iterations  54
# PLA converged after %d iterations  12
# PLA converged after %d iterations  225
# PLA converged after %d iterations  29
# PLA converged after %d iterations  13
# PLA converged after %d iterations  362
# PLA converged after %d iterations  14
# PLA converged after %d iterations  368
# PLA converged after %d iterations  201
# PLA converged after %d iterations  102
# PLA converged after %d iterations  52
# PLA converged after %d iterations  88
# PLA converged after %d iterations  113
# PLA converged after %d iterations  55
# PLA converged after %d iterations  805
# PLA converged after %d iterations  191
# PLA converged after %d iterations  65
# PLA converged after %d iterations  121
# PLA converged after %d iterations  177
# PLA converged after %d iterations  15
# PLA converged after %d iterations  20
# PLA converged after %d iterations  295
# PLA converged after %d iterations  146
# PLA converged after %d iterations  22
# PLA converged after %d iterations  7
# PLA converged after %d iterations  124
# PLA converged after %d iterations  32
# PLA converged after %d iterations  114
# PLA converged after %d iterations  475
# PLA converged after %d iterations  9
# PLA converged after %d iterations  245
# PLA converged after %d iterations  66
# PLA converged after %d iterations  85
# PLA converged after %d iterations  24
# PLA converged after %d iterations  881
# PLA converged after %d iterations  64
# PLA converged after %d iterations  30
# PLA converged after %d iterations  106
# PLA converged after %d iterations  70
# PLA converged after %d iterations  154
# PLA converged after %d iterations  133
# PLA converged after %d iterations  66
# PLA converged after %d iterations  31
# PLA converged after %d iterations  83
# PLA converged after %d iterations  24
# PLA converged after %d iterations  45
# PLA converged after %d iterations  22
# PLA converged after %d iterations  107
# PLA converged after %d iterations  97
# PLA converged after %d iterations  289
# PLA converged after %d iterations  14
# PLA converged after %d iterations  15
# PLA converged after %d iterations  93
# PLA converged after %d iterations  232
# PLA converged after %d iterations  81
# PLA converged after %d iterations  66
# PLA converged after %d iterations  145
# PLA converged after %d iterations  8
# PLA converged after %d iterations  23
# PLA converged after %d iterations  67
# PLA converged after %d iterations  44
# PLA converged after %d iterations  67
# PLA converged after %d iterations  27
# PLA converged after %d iterations  49
# PLA converged after %d iterations  78
# PLA converged after %d iterations  87
# PLA converged after %d iterations  17
# PLA converged after %d iterations  121
# PLA converged after %d iterations  37
# PLA converged after %d iterations  25
# PLA converged after %d iterations  12
# PLA converged after %d iterations  164
# PLA converged after %d iterations  65
# PLA converged after %d iterations  103
# PLA converged after %d iterations  96
# PLA converged after %d iterations  26
# PLA converged after %d iterations  72
# PLA converged after %d iterations  43
# PLA converged after %d iterations  23
# PLA converged after %d iterations  62
# PLA converged after %d iterations  56
# PLA converged after %d iterations  113
# PLA converged after %d iterations  30
# PLA converged after %d iterations  26
# PLA converged after %d iterations  136
# PLA converged after %d iterations  79
# PLA converged after %d iterations  110
# PLA converged after %d iterations  72
# PLA converged after %d iterations  47
# PLA converged after %d iterations  66
# PLA converged after %d iterations  83
# PLA converged after %d iterations  323
# PLA converged after %d iterations  13
# PLA converged after %d iterations  34
# PLA converged after %d iterations  30
# PLA converged after %d iterations  479
# PLA converged after %d iterations  33
# PLA converged after %d iterations  26
# PLA converged after %d iterations  43
# PLA converged after %d iterations  9
# PLA converged after %d iterations  28
# PLA converged after %d iterations  168
# PLA converged after %d iterations  62
# PLA converged after %d iterations  107
# PLA converged after %d iterations  48
# PLA converged after %d iterations  38
# PLA converged after %d iterations  175
# PLA converged after %d iterations  107
# PLA converged after %d iterations  133
# PLA converged after %d iterations  299
# PLA converged after %d iterations  42
# PLA converged after %d iterations  87
# PLA converged after %d iterations  48
# PLA converged after %d iterations  49
# PLA converged after %d iterations  114
# PLA converged after %d iterations  25
# PLA converged after %d iterations  149
# PLA converged after %d iterations  266
# PLA converged after %d iterations  38
# PLA converged after %d iterations  20
# PLA converged after %d iterations  369
# PLA converged after %d iterations  40
# PLA converged after %d iterations  129
# PLA converged after %d iterations  35
# PLA converged after %d iterations  291
# PLA converged after %d iterations  79
# PLA converged after %d iterations  34
# PLA converged after %d iterations  68
# PLA converged after %d iterations  40
# PLA converged after %d iterations  25
# PLA converged after %d iterations  53
# PLA converged after %d iterations  37
# PLA converged after %d iterations  81
# PLA converged after %d iterations  151
# PLA converged after %d iterations  22
# PLA converged after %d iterations  233
# PLA converged after %d iterations  74
# PLA converged after %d iterations  28
# PLA converged after %d iterations  38
# PLA converged after %d iterations  323
# PLA converged after %d iterations  99
# PLA converged after %d iterations  64
# PLA converged after %d iterations  22
# PLA converged after %d iterations  18
# PLA converged after %d iterations  78
# PLA converged after %d iterations  69
# PLA converged after %d iterations  107
# PLA converged after %d iterations  54
# PLA converged after %d iterations  79
# PLA converged after %d iterations  36
# PLA converged after %d iterations  41
# PLA converged after %d iterations  293
# PLA converged after %d iterations  87
# PLA converged after %d iterations  155
# PLA converged after %d iterations  170
# PLA converged after %d iterations  30
# PLA converged after %d iterations  174
# PLA converged after %d iterations  6
# PLA converged after %d iterations  71
# PLA converged after %d iterations  5
# PLA converged after %d iterations  151
# PLA converged after %d iterations  18
# PLA converged after %d iterations  70
# PLA converged after %d iterations  53
# PLA converged after %d iterations  29
# PLA converged after %d iterations  84
# PLA converged after %d iterations  18
# PLA converged after %d iterations  83
# PLA converged after %d iterations  17
# PLA converged after %d iterations  39
# PLA converged after %d iterations  99
# PLA converged after %d iterations  143
# PLA converged after %d iterations  27
# PLA converged after %d iterations  25
# PLA converged after %d iterations  56
# PLA converged after %d iterations  111
# PLA converged after %d iterations  37
# PLA converged after %d iterations  145
# PLA converged after %d iterations  11
# PLA converged after %d iterations  33
# PLA converged after %d iterations  10
# PLA converged after %d iterations  7117
# PLA converged after %d iterations  41
# PLA converged after %d iterations  131
# PLA converged after %d iterations  44
# PLA converged after %d iterations  192
# PLA converged after %d iterations  25
# PLA converged after %d iterations  62
# PLA converged after %d iterations  67
# PLA converged after %d iterations  83
# PLA converged after %d iterations  61
# PLA converged after %d iterations  54
# PLA converged after %d iterations  23
# PLA converged after %d iterations  64
# PLA converged after %d iterations  35
# PLA converged after %d iterations  85
# PLA converged after %d iterations  418
# PLA converged after %d iterations  27
# PLA converged after %d iterations  12
# PLA converged after %d iterations  118
# PLA converged after %d iterations  143
# PLA converged after %d iterations  61
# PLA converged after %d iterations  275
# PLA converged after %d iterations  1209
# PLA converged after %d iterations  88
# PLA converged after %d iterations  34
# PLA converged after %d iterations  37
# PLA converged after %d iterations  2345
# PLA converged after %d iterations  120
# PLA converged after %d iterations  15
# PLA converged after %d iterations  78
# PLA converged after %d iterations  92
# PLA converged after %d iterations  21
# PLA converged after %d iterations  36
# PLA converged after %d iterations  45
# PLA converged after %d iterations  65
# PLA converged after %d iterations  153
# PLA converged after %d iterations  20
# PLA converged after %d iterations  91
# PLA converged after %d iterations  2501
# PLA converged after %d iterations  12
# PLA converged after %d iterations  46
# PLA converged after %d iterations  22
# PLA converged after %d iterations  83
# PLA converged after %d iterations  46
# PLA converged after %d iterations  82
# PLA converged after %d iterations  55
# PLA converged after %d iterations  207
# PLA converged after %d iterations  7
# PLA converged after %d iterations  320
# PLA converged after %d iterations  47
# PLA converged after %d iterations  68
# PLA converged after %d iterations  131
# PLA converged after %d iterations  65
# PLA converged after %d iterations  81
# PLA converged after %d iterations  48
# PLA converged after %d iterations  69
# PLA converged after %d iterations  15
# PLA converged after %d iterations  57
# PLA converged after %d iterations  102
# PLA converged after %d iterations  28
# PLA converged after %d iterations  182
# PLA converged after %d iterations  49
# PLA converged after %d iterations  10
# PLA converged after %d iterations  39
# PLA converged after %d iterations  43
# PLA converged after %d iterations  138
# PLA converged after %d iterations  165
# PLA converged after %d iterations  64
# PLA converged after %d iterations  37
# PLA converged after %d iterations  16
# PLA converged after %d iterations  303
# PLA converged after %d iterations  69
# PLA converged after %d iterations  40
# PLA converged after %d iterations  224
# PLA converged after %d iterations  130
# PLA converged after %d iterations  77
# PLA converged after %d iterations  17
# PLA converged after %d iterations  17
# PLA converged after %d iterations  48
# PLA converged after %d iterations  88
# PLA converged after %d iterations  167
# PLA converged after %d iterations  14
# PLA converged after %d iterations  122
# PLA converged after %d iterations  463
# PLA converged after %d iterations  96
# PLA converged after %d iterations  105
# PLA converged after %d iterations  111
# PLA converged after %d iterations  281
# PLA converged after %d iterations  23
# PLA converged after %d iterations  89
# PLA converged after %d iterations  34
# PLA converged after %d iterations  95
# PLA converged after %d iterations  52
# PLA converged after %d iterations  89
# PLA converged after %d iterations  42
# PLA converged after %d iterations  48
# PLA converged after %d iterations  25
# PLA converged after %d iterations  51
# PLA converged after %d iterations  152
# PLA converged after %d iterations  36
# PLA converged after %d iterations  227
# PLA converged after %d iterations  101
# PLA converged after %d iterations  51
# PLA converged after %d iterations  58
# PLA converged after %d iterations  15
# PLA converged after %d iterations  84
# PLA converged after %d iterations  37
# PLA converged after %d iterations  42
# PLA converged after %d iterations  64
# PLA converged after %d iterations  17
# PLA converged after %d iterations  54
# PLA converged after %d iterations  33
# PLA converged after %d iterations  25
# PLA converged after %d iterations  123
# PLA converged after %d iterations  101
# PLA converged after %d iterations  23
# PLA converged after %d iterations  33
# PLA converged after %d iterations  61
# PLA converged after %d iterations  299
# PLA converged after %d iterations  47
# PLA converged after %d iterations  48
# PLA converged after %d iterations  41
# PLA converged after %d iterations  42
# PLA converged after %d iterations  20
# PLA converged after %d iterations  37
# PLA converged after %d iterations  16
# PLA converged after %d iterations  46
# PLA converged after %d iterations  47
# PLA converged after %d iterations  30
# PLA converged after %d iterations  129
# PLA converged after %d iterations  48
# PLA converged after %d iterations  27
# PLA converged after %d iterations  133
# PLA converged after %d iterations  81
# PLA converged after %d iterations  45
# PLA converged after %d iterations  33
# PLA converged after %d iterations  165
# PLA converged after %d iterations  31
# PLA converged after %d iterations  224
# PLA converged after %d iterations  15
# PLA converged after %d iterations  13
# PLA converged after %d iterations  47
# PLA converged after %d iterations  28
# PLA converged after %d iterations  301
# PLA converged after %d iterations  90
# PLA converged after %d iterations  12
# PLA converged after %d iterations  62
# PLA converged after %d iterations  48
# PLA converged after %d iterations  22
# PLA converged after %d iterations  402
# PLA converged after %d iterations  65
# PLA converged after %d iterations  38
# PLA converged after %d iterations  11
# PLA converged after %d iterations  23
# PLA converged after %d iterations  22
# PLA converged after %d iterations  151
# PLA converged after %d iterations  53
# PLA converged after %d iterations  123
# PLA converged after %d iterations  146
# PLA converged after %d iterations  62
# PLA converged after %d iterations  33
# PLA converged after %d iterations  118
# PLA converged after %d iterations  27
# PLA converged after %d iterations  34
# PLA converged after %d iterations  31
# PLA converged after %d iterations  59
# PLA converged after %d iterations  79
# PLA converged after %d iterations  66
# PLA converged after %d iterations  38
# PLA converged after %d iterations  876
# PLA converged after %d iterations  164
# PLA converged after %d iterations  163
# PLA converged after %d iterations  33
# PLA converged after %d iterations  61
# PLA converged after %d iterations  70
# PLA converged after %d iterations  51
# PLA converged after %d iterations  33
# PLA converged after %d iterations  61
# PLA converged after %d iterations  191
# PLA converged after %d iterations  82
# PLA converged after %d iterations  67
# PLA converged after %d iterations  127
# PLA converged after %d iterations  94
# PLA converged after %d iterations  27
# PLA converged after %d iterations  24
# PLA converged after %d iterations  154
# PLA converged after %d iterations  14
# PLA converged after %d iterations  110
# PLA converged after %d iterations  38
# PLA converged after %d iterations  75
# PLA converged after %d iterations  131
# PLA converged after %d iterations  18
# PLA converged after %d iterations  145
# PLA converged after %d iterations  157
# PLA converged after %d iterations  67
# PLA converged after %d iterations  135
# PLA converged after %d iterations  26
# PLA converged after %d iterations  54
# PLA converged after %d iterations  215
# PLA converged after %d iterations  63
# PLA converged after %d iterations  18
# PLA converged after %d iterations  103
# PLA converged after %d iterations  16
# PLA converged after %d iterations  369
# PLA converged after %d iterations  191
# PLA converged after %d iterations  45
# PLA converged after %d iterations  19
# PLA converged after %d iterations  63
# PLA converged after %d iterations  32
# PLA converged after %d iterations  55
# PLA converged after %d iterations  81
# PLA converged after %d iterations  685
# PLA converged after %d iterations  27
# PLA converged after %d iterations  25
# PLA converged after %d iterations  57
# PLA converged after %d iterations  104
# PLA converged after %d iterations  48
# PLA converged after %d iterations  93
# PLA converged after %d iterations  76
# PLA converged after %d iterations  127
# PLA converged after %d iterations  94
# PLA converged after %d iterations  623
# PLA converged after %d iterations  50
# PLA converged after %d iterations  83
# PLA converged after %d iterations  39
# PLA converged after %d iterations  116
# PLA converged after %d iterations  141
# PLA converged after %d iterations  37
# PLA converged after %d iterations  22
# PLA converged after %d iterations  97
# PLA converged after %d iterations  222
# PLA converged after %d iterations  133
# PLA converged after %d iterations  49
# PLA converged after %d iterations  272
# PLA converged after %d iterations  55
# PLA converged after %d iterations  68
# PLA converged after %d iterations  67
# PLA converged after %d iterations  136
# PLA converged after %d iterations  81
# PLA converged after %d iterations  495
# PLA converged after %d iterations  40
# PLA converged after %d iterations  41
# PLA converged after %d iterations  89
# PLA converged after %d iterations  138
# PLA converged after %d iterations  59
# PLA converged after %d iterations  103
# PLA converged after %d iterations  183
# PLA converged after %d iterations  44
# PLA converged after %d iterations  40
# PLA converged after %d iterations  102
# PLA converged after %d iterations  63
# PLA converged after %d iterations  40
# PLA converged after %d iterations  22
# PLA converged after %d iterations  70
# PLA converged after %d iterations  117
# PLA converged after %d iterations  284
# PLA converged after %d iterations  214
# PLA converged after %d iterations  54
# PLA converged after %d iterations  37
# PLA converged after %d iterations  12
# PLA converged after %d iterations  217
# PLA converged after %d iterations  60
# PLA converged after %d iterations  65
# PLA converged after %d iterations  40
# PLA converged after %d iterations  21
# PLA converged after %d iterations  63
# PLA converged after %d iterations  592
# PLA converged after %d iterations  70
# PLA converged after %d iterations  22
# PLA converged after %d iterations  46
# PLA converged after %d iterations  112
# PLA converged after %d iterations  99
# PLA converged after %d iterations  23
# PLA converged after %d iterations  63
# PLA converged after %d iterations  28
# PLA converged after %d iterations  316
# PLA converged after %d iterations  47
# PLA converged after %d iterations  211
# PLA converged after %d iterations  111
# PLA converged after %d iterations  27
# PLA converged after %d iterations  70
# PLA converged after %d iterations  27
# PLA converged after %d iterations  210
# PLA converged after %d iterations  69
# PLA converged after %d iterations  64
# PLA converged after %d iterations  49
# PLA converged after %d iterations  563
# PLA converged after %d iterations  103
# PLA converged after %d iterations  38
# PLA converged after %d iterations  119
# PLA converged after %d iterations  223
# PLA converged after %d iterations  299
# PLA converged after %d iterations  23
# PLA converged after %d iterations  84
# PLA converged after %d iterations  122
# PLA converged after %d iterations  157
# PLA converged after %d iterations  15
# PLA converged after %d iterations  54
# PLA converged after %d iterations  22
# PLA converged after %d iterations  89
# PLA converged after %d iterations  44
# PLA converged after %d iterations  26
# PLA converged after %d iterations  28
# PLA converged after %d iterations  69
# PLA converged after %d iterations  344
# PLA converged after %d iterations  20
# PLA converged after %d iterations  15
# PLA converged after %d iterations  29
# PLA converged after %d iterations  11
# PLA converged after %d iterations  266
# PLA converged after %d iterations  99
# PLA converged after %d iterations  19
# PLA converged after %d iterations  64
# PLA converged after %d iterations  89
# PLA converged after %d iterations  201
# PLA converged after %d iterations  55
# PLA converged after %d iterations  51
# PLA converged after %d iterations  33
# PLA converged after %d iterations  98
# PLA converged after %d iterations  75
# PLA converged after %d iterations  69
# PLA converged after %d iterations  11
# PLA converged after %d iterations  34
# PLA converged after %d iterations  175
# PLA converged after %d iterations  2429
# PLA converged after %d iterations  76
# PLA converged after %d iterations  118
# PLA converged after %d iterations  93
# PLA converged after %d iterations  59
# PLA converged after %d iterations  15
# PLA converged after %d iterations  67
# PLA converged after %d iterations  129
# PLA converged after %d iterations  94
# PLA converged after %d iterations  96
# PLA converged after %d iterations  71
# PLA converged after %d iterations  1953
# PLA converged after %d iterations  78
# PLA converged after %d iterations  14
# PLA converged after %d iterations  15
# PLA converged after %d iterations  31
# PLA converged after %d iterations  133
# PLA converged after %d iterations  14
# PLA converged after %d iterations  88
# PLA converged after %d iterations  22
# PLA converged after %d iterations  41
# PLA converged after %d iterations  26
# PLA converged after %d iterations  79
# PLA converged after %d iterations  243
# PLA converged after %d iterations  35
# PLA converged after %d iterations  15
# PLA converged after %d iterations  72
# PLA converged after %d iterations  204
# PLA converged after %d iterations  52
# PLA converged after %d iterations  4
# PLA converged after %d iterations  31
# PLA converged after %d iterations  31
# PLA converged after %d iterations  73
# PLA converged after %d iterations  35
# PLA converged after %d iterations  67
# PLA converged after %d iterations  52
# PLA converged after %d iterations  10
# PLA converged after %d iterations  32
# PLA converged after %d iterations  33
# PLA converged after %d iterations  41
# PLA converged after %d iterations  20
# PLA converged after %d iterations  96
# PLA converged after %d iterations  152
# PLA converged after %d iterations  91
# PLA converged after %d iterations  22
# PLA converged after %d iterations  65
# PLA converged after %d iterations  41
# PLA converged after %d iterations  199
# PLA converged after %d iterations  2541
# PLA converged after %d iterations  61
# PLA converged after %d iterations  175
# PLA converged after %d iterations  74
# PLA converged after %d iterations  29
# PLA converged after %d iterations  39
# PLA converged after %d iterations  111
# PLA converged after %d iterations  311
# PLA converged after %d iterations  38
# PLA converged after %d iterations  71
# PLA converged after %d iterations  38
# PLA converged after %d iterations  66
# PLA converged after %d iterations  147
# PLA converged after %d iterations  116
# PLA converged after %d iterations  46
# PLA converged after %d iterations  508
# PLA converged after %d iterations  44
# PLA converged after %d iterations  70
# PLA converged after %d iterations  14
# PLA converged after %d iterations  67
# PLA converged after %d iterations  120
# PLA converged after %d iterations  84
# PLA converged after %d iterations  35
# PLA converged after %d iterations  46
# PLA converged after %d iterations  90
# PLA converged after %d iterations  18
# PLA converged after %d iterations  45
# PLA converged after %d iterations  64
# PLA converged after %d iterations  43
# PLA converged after %d iterations  47
# PLA converged after %d iterations  47
# PLA converged after %d iterations  111
# PLA converged after %d iterations  67
# PLA converged after %d iterations  2
# PLA converged after %d iterations  59
# PLA converged after %d iterations  22
# PLA converged after %d iterations  142
# PLA converged after %d iterations  150
# PLA converged after %d iterations  32
# PLA converged after %d iterations  21
# PLA converged after %d iterations  230
# PLA converged after %d iterations  56
# PLA converged after %d iterations  171
# PLA converged after %d iterations  25
# PLA converged after %d iterations  32
# PLA converged after %d iterations  154
# PLA converged after %d iterations  129
# PLA converged after %d iterations  64
# PLA converged after %d iterations  107
# PLA converged after %d iterations  144
# PLA converged after %d iterations  94
# PLA converged after %d iterations  58
# PLA converged after %d iterations  117
# PLA converged after %d iterations  80
# PLA converged after %d iterations  214
# PLA converged after %d iterations  65
# PLA converged after %d iterations  46
# PLA converged after %d iterations  193
# PLA converged after %d iterations  78
# PLA converged after %d iterations  36
# PLA converged after %d iterations  387
# PLA converged after %d iterations  30
# PLA converged after %d iterations  30
# PLA converged after %d iterations  38
# PLA converged after %d iterations  16
# PLA converged after %d iterations  49
# PLA converged after %d iterations  86
# PLA converged after %d iterations  160
# PLA converged after %d iterations  67
# PLA converged after %d iterations  26
# PLA converged after %d iterations  66
# PLA converged after %d iterations  51
# PLA converged after %d iterations  555
# PLA converged after %d iterations  77
# PLA converged after %d iterations  47
# PLA converged after %d iterations  133
# PLA converged after %d iterations  12
# PLA converged after %d iterations  149
# PLA converged after %d iterations  55
# PLA converged after %d iterations  69
# PLA converged after %d iterations  35
# PLA converged after %d iterations  40
# PLA converged after %d iterations  36
# PLA converged after %d iterations  263
# PLA converged after %d iterations  9
# PLA converged after %d iterations  43
# PLA converged after %d iterations  115
# PLA converged after %d iterations  33
# PLA converged after %d iterations  49
# PLA converged after %d iterations  86
# PLA converged after %d iterations  19
# PLA converged after %d iterations  10
# PLA converged after %d iterations  493
# PLA converged after %d iterations  113
# PLA converged after %d iterations  109
# PLA converged after %d iterations  13
# PLA converged after %d iterations  175
# PLA converged after %d iterations  223
# PLA converged after %d iterations  116
# PLA converged after %d iterations  43
# PLA converged after %d iterations  42
# PLA converged after %d iterations  19
# PLA converged after %d iterations  56
# PLA converged after %d iterations  899
# PLA converged after %d iterations  34
# PLA converged after %d iterations  166
# PLA converged after %d iterations  233
# PLA converged after %d iterations  49
# PLA converged after %d iterations  33
# PLA converged after %d iterations  43
# PLA converged after %d iterations  29
# PLA converged after %d iterations  20
# PLA converged after %d iterations  53
# PLA converged after %d iterations  95
# PLA converged after %d iterations  120
# PLA converged after %d iterations  38
# PLA converged after %d iterations  75
# PLA converged after %d iterations  471
# PLA converged after %d iterations  38
# PLA converged after %d iterations  58
# PLA converged after %d iterations  54
# PLA converged after %d iterations  35
# PLA converged after %d iterations  25
# PLA converged after %d iterations  78
# PLA converged after %d iterations  119
# PLA converged after %d iterations  64
# PLA converged after %d iterations  46
# PLA converged after %d iterations  89
# PLA converged after %d iterations  136
# PLA converged after %d iterations  93
# PLA converged after %d iterations  49
# PLA converged after %d iterations  28
# PLA converged after %d iterations  49
# PLA converged after %d iterations  5
# PLA converged after %d iterations  51
# PLA converged after %d iterations  151
# PLA converged after %d iterations  16
# PLA converged after %d iterations  39
# PLA converged after %d iterations  24
# PLA converged after %d iterations  145
# PLA converged after %d iterations  14
# PLA converged after %d iterations  106
# PLA converged after %d iterations  132
# PLA converged after %d iterations  21
# PLA converged after %d iterations  541
# PLA converged after %d iterations  34
# PLA converged after %d iterations  10
# PLA converged after %d iterations  183
# PLA converged after %d iterations  45
# PLA converged after %d iterations  50
# PLA converged after %d iterations  31
# PLA converged after %d iterations  67
# PLA converged after %d iterations  29
# PLA converged after %d iterations  217
# PLA converged after %d iterations  97
# PLA converged after %d iterations  32
# PLA converged after %d iterations  31
# PLA converged after %d iterations  59
# PLA converged after %d iterations  47
# PLA converged after %d iterations  50
# PLA converged after %d iterations  17
# PLA converged after %d iterations  13
# PLA converged after %d iterations  12
# PLA converged after %d iterations  31
# PLA converged after %d iterations  14
# PLA converged after %d iterations  206
# PLA converged after %d iterations  66
# PLA converged after %d iterations  11
# PLA converged after %d iterations  41
# PLA converged after %d iterations  39
# PLA converged after %d iterations  365
# PLA converged after %d iterations  157
# PLA converged after %d iterations  27
# PLA converged after %d iterations  48
# PLA converged after %d iterations  20
# PLA converged after %d iterations  57
# PLA converged after %d iterations  50
# PLA converged after %d iterations  143
# PLA converged after %d iterations  67
# PLA converged after %d iterations  126
# PLA converged after %d iterations  28
# PLA converged after %d iterations  26
# PLA converged after %d iterations  203
# PLA converged after %d iterations  37
# PLA converged after %d iterations  41
# PLA converged after %d iterations  156
# PLA converged after %d iterations  13
# PLA converged after %d iterations  39
# PLA converged after %d iterations  213
# PLA converged after %d iterations  94
# PLA converged after %d iterations  272
# PLA converged after %d iterations  32
# PLA converged after %d iterations  144
# PLA converged after %d iterations  60
# PLA converged after %d iterations  197
# PLA converged after %d iterations  75
# PLA converged after %d iterations  10
# PLA converged after %d iterations  120
# PLA converged after %d iterations  97
# PLA converged after %d iterations  21
# PLA converged after %d iterations  283
# PLA converged after %d iterations  7
# PLA converged after %d iterations  24
# PLA converged after %d iterations  19
# PLA converged after %d iterations  28
# PLA converged after %d iterations  28
# PLA converged after %d iterations  94
# PLA converged after %d iterations  96
# PLA converged after %d iterations  239
# PLA converged after %d iterations  108
# PLA converged after %d iterations  15
# PLA converged after %d iterations  79
# PLA converged after %d iterations  50
# PLA converged after %d iterations  58
# PLA converged after %d iterations  147
# PLA converged after %d iterations  22
# PLA converged after %d iterations  130
# PLA converged after %d iterations  84
# PLA converged after %d iterations  148
# PLA converged after %d iterations  196
# PLA converged after %d iterations  80
# PLA converged after %d iterations  43
# PLA converged after %d iterations  61
# PLA converged after %d iterations  109
# PLA converged after %d iterations  72
# PLA converged after %d iterations  190
# PLA converged after %d iterations  30
# PLA converged after %d iterations  135
# PLA converged after %d iterations  68
# PLA converged after %d iterations  19
# PLA converged after %d iterations  204
# PLA converged after %d iterations  59
# PLA converged after %d iterations  84
# PLA converged after %d iterations  156
# PLA converged after %d iterations  6
# PLA converged after %d iterations  139
# PLA converged after %d iterations  155
# PLA converged after %d iterations  24
# PLA converged after %d iterations  216
# PLA converged after %d iterations  59
# PLA converged after %d iterations  28
# PLA converged after %d iterations  112
# PLA converged after %d iterations  131
# ----------------------------------
# The average number of iterations =  113.527

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [b]

# %% [markdown]
# ## Câu 10 (1 điểm)

# %%
print("the average disagreement probability between f and g = ", mean_disagreementProb)
# Out:
# the average disagreement probability between f and g =  0.013304999999999933

# %% [markdown]
# YOUR ANSWER HERE
# - Do đó em chọn đáp án [b]
